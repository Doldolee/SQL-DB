# %%
import pymysql

# %%
db = pymysql.connect(host='localhost', port=3306, user='root', passwd='6853', db='ecommerce', charset='utf8')

# %%
db

# %%
ecommerce = db.cursor()

# %%
cpudata

# %%
sql = '''
    CREATE TABLE product(
        PRODUCT_CODE VARCHAR(20) NOT NULL,
        TITLE VARCHAR(200) NOT NULL,
        ORI_PRICE INT,
        DISCOUNT_PRICE INT,
        DISCOUNT_PERCENT INT,
        DELIVERY VARCHAR(2),
        PRIMARY KEY(PRODUCT_CODE)
    );'''

# %%
ecommerce.execute(sql)
# Out:
# 0

# %%
db.commit()

# %%
db.close()

# %%
import pymysql

db = pymysql.connect(host='localhost', port=3306, user='root', passwd='6853', db='ecommerce', charset='utf8')
ecommerce = db.cursor()
sql = '''
    INSERT INTO product VALUES(
    '215673140', '스위트바니 여름신상5900원-롱원피스티셔츠/긴팔.반팔',23000,6900,70,'F');'''

ecommerce.execute(sql)
db.commit()
db.close()

# %%
import pymysql
db = pymysql.connect(host='localhost', port=3306, user='root', passwd='6853', db = 'ecommerce', charset='utf8')
ecommerce = db.cursor()
sql = '''
    SELECT * FROM product'''
ecommerce.execute(sql)

result = ecommerce.fetchall()
for record in result:
    print(record[0])
db.close()
# Out:
# 215673140

# %%
import pymysql
db = pymysql.connect(host='localhost',port=3306, user='root', passwd='6853', db='ecommerce', charset='utf8')
db.cursor()

for x in range(10):
    product_code = 215673140 + x + 1
    sql = '''
    INSERT INTO product VALUES(
    '"str(product_code)"', '스위트바니 여름신상5900원-롱원피스티셔츠/긴팔.반팔',23000,6900,70,'F');'''
    print(sql)
# Out:
#     INSERT INTO product VALUES(
#     '"str(product_code)"', '스위트바니 여름신상5900원-롱원피스티셔츠/긴팔.반팔',23000,6900,70,'F');
#
#     INSERT INTO product VALUES(
#     '"str(product_code)"', '스위트바니 여름신상5900원-롱원피스티셔츠/긴팔.반팔',23000,6900,70,'F');
#
#     INSERT INTO product VALUES(
#     '"str(product_code)"', '스위트바니 여름신상5900원-롱원피스티셔츠/긴팔.반팔',23000,6900,70,'F');
#
#     INSERT INTO product VALUES(
#     '"str(product_code)"', '스위트바니 여름신상5900원-롱원피스티셔츠/긴팔.반팔',23000,6900,70,'F');
#
#     INSERT INTO product VALUES(
#     '"str(product_code)"', '스위트바니 여름신상5900원-롱원피스티셔츠/긴팔.반팔',23000,6900,70,'F');
#
#     INSERT INTO product VALUES(
#     '"str(product_code)"', '스위트바니 여름신상5900원-롱원피스티셔츠/긴팔.반팔',23000,6900,70,'F');
#
#     INSERT INTO product VALUES(
#     '"str(product_code)"', '스위트바니 여름신상5900원-롱원피스티셔츠/긴팔.반팔',23000,6900,70,'F');
#
#     INSERT INTO product VALUES(
#     '"str(product_code)"', '스위트바니 여름신상5900원-롱원피스티셔츠/긴팔.반팔',23000,6900,70,'F');
#
#     INSERT INTO product VALUES(
#     '"str(product_code)"', '스위트바니 여름신상5900원-롱원피스티셔츠/긴팔.반팔',23000,6900,70,'F');
#
#     INSERT INTO product VALUES(
#     '"str(product_code)"', '스위트바니 여름신상5900원-롱원피스티셔츠/긴팔.반팔',23000,6900,70,'F');

# %%
import pymysql

db = pymysql.connect(host='localhost',port=3306, user='root', passwd='6853', db='ecommerce', charset='utf8')

ecommerce = db.cursor()

for x in range(10):
    product_code = 215673140 + x + 1
    sql = '''
        INSERT INTO product VALUES(
        "'''+str(product_code)+'''",'스위트바니 여름신상','23000','6900','70','F');'''
    ecommerce.execute(sql)

db.commit()
db.close()

# %%
import pymysql

db=pymysql.connect(host='localhost',port=3306, user='root', passwd='6853', db='ecommerce',charset='utf8')
ecommerce = db.cursor()
sql = 'SELECT * FROM product'
ecommerce.execute(sql)
result = ecommerce.fetchall()
for x in result:
    print(x)
db.close()
# Out:
# ('215673140', '스위트바니 여름신상5900원-롱원피스티셔츠/긴팔.반팔', 23000, 6900, 70, 'F')
# ('215673141', '스위트바니 여름신상', 23000, 6900, 70, 'F')
# ('215673142', '스위트바니 여름신상', 23000, 6900, 70, 'F')
# ('215673143', '스위트바니 여름신상', 23000, 6900, 70, 'F')
# ('215673144', '스위트바니 여름신상', 23000, 6900, 70, 'F')
# ('215673145', '스위트바니 여름신상', 23000, 6900, 70, 'F')
# ('215673146', '스위트바니 여름신상', 23000, 6900, 70, 'F')
# ('215673147', '스위트바니 여름신상', 23000, 6900, 70, 'F')
# ('215673148', '스위트바니 여름신상', 23000, 6900, 70, 'F')
# ('215673149', '스위트바니 여름신상', 23000, 6900, 70, 'F')
# ('215673150', '스위트바니 여름신상', 23000, 6900, 70, 'F')

# %%
import pymysql

db = pymysql.connect(host='localhost',port=3306, user='root',passwd='6853',db='ecommerce',charset='utf8')
ecommerce = db.cursor()
sql ="""
    UPDATE product SET
        TITLE='달리샵 린넨 원피스',
        ORI_PRICE=33000,
        DISCOUNT_PRICE=9900,
        DISCOUNT_PERCENT=70
        WHERE PRODUCT_CODE = '215673148'
"""
ecommerce.execute(sql)
db.commit()
db.close()

# %%
import pymysql
import pandas as pd

# %%
db = pymysql.connect(host='localhost',port=3306, user='root',passwd='6853',db='student_mgmt',charset='utf8')

# %%
sql = 'SHOW TABLES'
sql2 = 'SELECT * FROM students'

# %%
df = pd.read_sql(sql2,db)
df
# Out:
#    id  NAME gender       birth  english  math  korean
# 0   1  andy  woman  1981-07-16       91    20      11
# 1   2  andy  woman  1981-07-16       91    20      11

# %%
df.to_csv('students.csv', sep=',', encoding='utf-8', index=False)

# %%
import pymysql
import pandas as pd

# %%
db = pymysql.connect(host='localhost',port=3306, user='root',passwd='6853',db='sqlDB',charset='utf8')

# %%
sql = 'SELECT * FROM userTBI'
df = pd.read_sql(sql,db)
df
# Out:
#   userID name  birthYear addr mobile1   mobile2  height       mDate
# 0    BBK  바비킴       1973   서울     010  00000000     176  2013-05-05
# 1    EJW  은지원       1972   경북     011  88888888     174  2014-03-03
# 2    JKW  조관우       1965   경기     016  99999999     172  2010-10-10
# 3    JYP  조용필       1950   경기     011  44444444     166  2009-04-04
# 4    KBS  김범수       1979   경남     011  22222222     173  2012-04-04
# 5    KKH  김경호       1971   전남     019  33333333     177  2007-07-07
# 6    LJB  임재범       1963   서울     016  66666666     182  2009-09-09
# 7    LSG  이승기       1987   서울     011  11111111     182  2008-08-08
# 8    SSK  성시경       1979   서울    None      None     186  2013-12-12
# 9    YJS  윤종신       1960   경남    None      None     170  2005-05-05

# %%
CREATE TABLE ranking (
    num INT AUTO_INCREMENT NOT NULL PRIMARY KEY,
    main_category VARCHAR(50) NOT NULL,
    sub_category VARCHAR(50) NOT NULL,
    item ranking TINYINT UNSIGNED NOT NULL,
    item_code VARCHAR(20) NOT NULL,
    FOREIGN KEY (item_code) REFERENCES items(item_code));

CREATE TABLE items (
    item_code VARCHAR(20) NOT NULL PRIMARY KEY,
    title VARCHAR(200) NOT NULL,
    ori_price INT NOT NULL,
    dis_price INT NOT NULL,
    discount_percent INT NOT NULL,
    provider VARCHAR(100)
);

# %%
import pymysql
db = pymysql.connect(host='localhost',port=3306, user='root', passwd='6853', db='bestproducts',charset='utf8')
cursor=db.cursor()
sql='''
    CREATE TABLE items (
    item_code VARCHAR(20) NOT NULL PRIMARY KEY,
    title VARCHAR(200) NOT NULL,
    ori_price INT NOT NULL,
    dis_price INT NOT NULL,
    discount_percent INT NOT NULL,
    provider VARCHAR(100)
);
'''
cursor.execute(sql)
sql = '''
CREATE TABLE ranking (
    num INT AUTO_INCREMENT NOT NULL PRIMARY KEY,
    main_category VARCHAR(50) NOT NULL,
    sub_category VARCHAR(50) NOT NULL,
    item_ranking TINYINT UNSIGNED NOT NULL,
    item_code VARCHAR(20) NOT NULL,
    FOREIGN KEY (item_code) REFERENCES items(item_code));
'''
cursor.execute(sql)
db.commit()
db.close()

# %%
import pymysql
db = pymysql.connect(host ='localhost', port=3306, user='root', passwd='6853', db='bestproducts', charset='utf8')
cursor = db.cursor()
sql='''

'''
db.commit()
db.close()

# %% [markdown]
# ###크롤링

# %% [markdown]
# main category 정보 가져오기

# %%
import requests
from bs4 import BeautifulSoup as bs
import pymysql
db = pymysql.connect(host ='localhost', port=3306, user='root', passwd='6853', db='bestproducts', charset='utf8')
cursor = db.cursor()

res = requests.get('http://corners.gmarket.co.kr/Bestsellers')
soup = bs(res.content, 'html.parser')

categories = soup.select('div.gbest-cate ul.by-group li a')
for category in categories:
    get_category('http://corners.gmarket.co.kr/'+category['href'], category.get_text())
# Out:
# http://corners.gmarket.co.kr//Bestsellers ALL
# INSERT INTO items VALUES('1993051414&ver',
#         '[Gfresh]우거지가 통째로 진짜 등뼈감자탕 4.7kg 10인분 대단량',
#         29900,
#         20900,
#         0,
#         'Gfresh')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '1',
#     '1993051414&ver')
# INSERT INTO items VALUES('1817237042&ver',
#         '패션페스타22%+카드10% 원피스/투피스 9290원 균일가',
#         39600,
#         11900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '2',
#     '1817237042&ver')
# INSERT INTO items VALUES('1583079155&ver',
#         '성주 꿀 참외 5kg이내 (크기랜덤) 가정용',
#         39800,
#         19900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '3',
#     '1583079155&ver')
# INSERT INTO items VALUES('1373777190&ver',
#         '패션페스타22% 쉬블림로브 신상 블라우스 셔츠 원피스',
#         33000,
#         9900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '4',
#     '1373777190&ver')
# INSERT INTO items VALUES('2036145620&ver',
#         '[마르조]패션페스타22% 마르조 단하루의 페스티벌 구매찬스',
#         56300,
#         16900,
#         0,
#         '마르조')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '5',
#     '2036145620&ver')
# INSERT INTO items VALUES('2026383365&ver',
#         '아람  감성과 지식을 더해주는 베토벤 음악동화 전10권 (세이펜 활용가능)',
#         80000,
#         69630,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '6',
#     '2026383365&ver')
# INSERT INTO items VALUES('197555399&ver',
#         '투투/패션페스타22%/봄신상 청바지/슬랙스/배기 5XL',
#         33000,
#         9900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '7',
#     '197555399&ver')
# INSERT INTO items VALUES('1326948653&ver',
#         '패션페스타22% 피핀 봄신상/1+1/티셔츠/원피스/팬츠',
#         49600,
#         14900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '8',
#     '1326948653&ver')
# INSERT INTO items VALUES('1624900645&ver',
#         '[이너리즘]심리스 스포츠 브라탑 4종기획세트/노라인팬티 5종',
#         41300,
#         12400,
#         0,
#         '이너리즘')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '9',
#     '1624900645&ver')
# INSERT INTO items VALUES('1764397632&ver',
#         '패션페스타22%/홈쇼핑브랜드 S/S 신상특가전/무료배송',
#         49600,
#         14900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '10',
#     '1764397632&ver')
# INSERT INTO items VALUES('1505849976&ver',
#         '[유한양행]해피홈 알콜스왑 소독솜 100매 4박스 +클리어키트 증정',
#         23800,
#         11900,
#         0,
#         '유한양행')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '11',
#     '1505849976&ver')
# INSERT INTO items VALUES('1871741696&ver',
#         '[매일두유]매일두유 검은콩 190ml 48팩 (쿠폰가15900원)',
#         30900,
#         18900,
#         0,
#         '매일유업')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '12',
#     '1871741696&ver')
# INSERT INTO items VALUES('1840147374&ver',
#         '[한국투자증권](한국투자증권) 온라인 금융상품권 5만원',
#         50000,
#         50000,
#         0,
#         '한국투자증권')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '13',
#     '1840147374&ver')
# INSERT INTO items VALUES('2052860857&ver',
#         '[크록스][모다아울렛]정품 바야밴드 아동샌들 클로그 205100-410',
#         31900,
#         29670,
#         0,
#         '크록스')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '14',
#     '2052860857&ver')
# INSERT INTO items VALUES('2035048314&ver',
#         '[Gfresh]산과들에 하루 한줌 견과류 원데이프리미엄 100낱봉',
#         83800,
#         41900,
#         0,
#         'Gfresh')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '15',
#     '2035048314&ver')
# INSERT INTO items VALUES('502114157&ver',
#         '패션페스타22% 코코리 쿠폰 봄신상박스롱후드맨투맨',
#         33000,
#         9900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '16',
#     '502114157&ver')
# INSERT INTO items VALUES('1894439744&ver',
#         '[델포유] 오븐에 구운 십센치 파운드 케이크 20개입',
#         12900,
#         12900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '17',
#     '1894439744&ver')
# INSERT INTO items VALUES('2057518393&ver',
#         'DIY멀티정리함',
#         23900,
#         7900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '18',
#     '2057518393&ver')
# INSERT INTO items VALUES('1615409666&ver',
#         '패션페스타22% 봄신상/원피스/블라우스/스커트/티셔츠',
#         39600,
#         11900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '19',
#     '1615409666&ver')
# INSERT INTO items VALUES('705589608&ver',
#         '[토니모리]3월 빅세일 20%+22%쿠폰+전품목 할인축제',
#         40000,
#         15000,
#         0,
#         '토니모리')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '20',
#     '705589608&ver')
# INSERT INTO items VALUES('1256823118&ver',
#         '[블루레이스](패션페스타22%)블루레이스 2021 봄신상OPEN',
#         64000,
#         19200,
#         0,
#         '블루레이스')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '21',
#     '1256823118&ver')
# INSERT INTO items VALUES('1311171220&ver',
#         '패션페스타22% 봄 파자마/잠옷/잠옷바지/주니어잠옷',
#         19600,
#         5900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '22',
#     '1311171220&ver')
# INSERT INTO items VALUES('2065087620&ver',
#         '우리아이 리더스의 첫걸음은 매버릭 어얼리 리더스로/Maverick Early Readers (3주내배송)',
#         150000,
#         95800,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '23',
#     '2065087620&ver')
# INSERT INTO items VALUES('2037084398&ver',
#         '엘다 에비히 IH 후라이팬 1+1 2종-모든열원가능',
#         45000,
#         16900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '24',
#     '2037084398&ver')
# INSERT INTO items VALUES('1787960274&ver',
#         '브리치x한미미 패션페스타22% T셔츠/맨투맨/니트',
#         48300,
#         14500,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '25',
#     '1787960274&ver')
# INSERT INTO items VALUES('798413703&ver',
#         '[투투삭스]봄신상 페이크삭스/덧신/패션양말/스니커즈/학생',
#         23000,
#         6900,
#         0,
#         '투투삭스')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '26',
#     '798413703&ver')
# INSERT INTO items VALUES('1636870532&ver',
#         '[Gfresh]국내산 조림 볶음용 지리 멸치 1kg/ 9160원 20% 쿠폰가',
#         19900,
#         11900,
#         0,
#         'Gfresh')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '27',
#     '1636870532&ver')
# INSERT INTO items VALUES('1871744619&ver',
#         '[매일두유]매일두유 99.89 190ml 24팩+검은콩 두유 190ml 24팩',
#         30900,
#         18900,
#         0,
#         '매일유업')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '28',
#     '1871744619&ver')
# INSERT INTO items VALUES('1817538454&ver',
#         '[다우니]다우니 엑스퍼트 실내 건조 1L 6개 +사은품',
#         49800,
#         29860,
#         0,
#         '다우니')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '29',
#     '1817538454&ver')
# INSERT INTO items VALUES('1867088468&ver',
#         '[컬럼비아][컬럼비아] 남녀 시프트 트레킹화 BM0081 BL0081',
#         79000,
#         53720,
#         0,
#         '컬럼비아')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '30',
#     '1867088468&ver')
# INSERT INTO items VALUES('1267464808&ver',
#         '[게스]22% 추가할인 GUESS 반팔티셔츠 대전',
#         66000,
#         20000,
#         0,
#         '게스')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '31',
#     '1267464808&ver')
# INSERT INTO items VALUES('1728114361&ver',
#         '[동원에프앤비]동원 인포켓 치즈 오리지널 (스트링치즈) 20g x 40개',
#         30400,
#         21300,
#         0,
#         '동원에프앤비')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '32',
#     '1728114361&ver')
# INSERT INTO items VALUES('2051988030&ver',
#         '[잭필드]잭필드  21SS 신상 봄 숨쉬는 바지 3종',
#         59800,
#         52530,
#         0,
#         '잭필드')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '33',
#     '2051988030&ver')
# INSERT INTO items VALUES('1510637585&ver',
#         '[스파클]스파클생수 2L 30병',
#         27800,
#         14600,
#         0,
#         '스파클')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '34',
#     '1510637585&ver')
# INSERT INTO items VALUES('2019096400&ver',
#         'ARS 5 000D원 할인  [바다소풍]완도 특大활전복 20미(미당80g~90g)',
#         59900,
#         59900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '35',
#     '2019096400&ver')
# INSERT INTO items VALUES('1674710974&ver',
#         '60수 아사 차렵이불+베개커버세트 (슈퍼싱글/퀸)',
#         37900,
#         14400,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '36',
#     '1674710974&ver')
# INSERT INTO items VALUES('1880627773&ver',
#         '[김나운더키친]김나운  떡갈비 명작 18팩/총36장',
#         32900,
#         32900,
#         0,
#         '김나운더키친')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '37',
#     '1880627773&ver')
# INSERT INTO items VALUES('1779696398&ver',
#         '[테크]테크 파워 액체세제(겸용) 대용량 8L',
#         16900,
#         10800,
#         0,
#         '테크')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '38',
#     '1779696398&ver')
# INSERT INTO items VALUES('1577525154&ver',
#         '브리치x허니제이 패션페스타22% 니트/가디건/맨투맨',
#         47600,
#         14300,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '39',
#     '1577525154&ver')
# INSERT INTO items VALUES('1655242371&ver',
#         '[구글플레이](카드가능) 기프트코드 10만원 / 구글 기프트카드',
#         100000,
#         95000,
#         0,
#         '구글플레이')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '40',
#     '1655242371&ver')
# INSERT INTO items VALUES('1634649304&ver',
#         '[파스퇴르]파스퇴르 전용목장 200mL 흰 멸균우유 18입 X2 (36입)',
#         22900,
#         21900,
#         0,
#         '파스퇴르')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '41',
#     '1634649304&ver')
# INSERT INTO items VALUES('2050347928&ver',
#         '[Gfresh]바삭바삭 광천 모둠 김자반 50g X 10봉/20%추가쿠폰',
#         18200,
#         10900,
#         0,
#         'Gfresh')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '42',
#     '2050347928&ver')
# INSERT INTO items VALUES('1667635785&ver',
#         '[드릴펑]배수구 세정제 드릴펑 1Lx4개+퍼펙트300mlx2개',
#         27250,
#         10900,
#         0,
#         '피죤')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '43',
#     '1667635785&ver')
# INSERT INTO items VALUES('801815493&ver',
#         '패션페스타22% 1+1 냉감티 트레이닝바지 등산바지',
#         36300,
#         10900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '44',
#     '801815493&ver')
# INSERT INTO items VALUES('1896210962&ver',
#         '[헤드앤숄더]헤드앤숄더 가려운 두피케어 샴푸 850ml 4개 +미니2개',
#         58000,
#         22900,
#         0,
#         '헤드앤숄더')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '45',
#     '1896210962&ver')
# INSERT INTO items VALUES('226919468&ver',
#         '월튼키즈 봄신상/신학기룩/상하복/티셔츠/원피스外',
#         33000,
#         9900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '46',
#     '226919468&ver')
# INSERT INTO items VALUES('1473200826&ver',
#         '[스팸]스팸 클래식 340g 10개',
#         31900,
#         26900,
#         0,
#         '스팸')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '47',
#     '1473200826&ver')
# INSERT INTO items VALUES('159718835&ver',
#         '[아침농산]국산 찰흑미 500g x 4개 2020년산 햅쌀',
#         15800,
#         7900,
#         0,
#         '아침농산')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '48',
#     '159718835&ver')
# INSERT INTO items VALUES('189842449&ver',
#         '요즘에/패션페스타22%+10%/청바지/슬랙스/면팬츠/3XL',
#         33000,
#         9900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '49',
#     '189842449&ver')
# INSERT INTO items VALUES('2060866631&ver',
#         '스테비아 방울토마토(샤인마토) 400g x 4팩  총 1.6kg',
#         30900,
#         28500,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '50',
#     '2060866631&ver')
# INSERT INTO items VALUES('2041520546&ver',
#         '[Gfresh]미스타셰프 버섯뚝배기불고기 400g 5팩/2kg/간편식',
#         21900,
#         16900,
#         0,
#         'Gfresh')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '51',
#     '2041520546&ver')
# INSERT INTO items VALUES('1837316797&ver',
#         '[매일유업]데르뜨 떠먹는젤리 복숭아 90g 24개/젤리',
#         19900,
#         12900,
#         0,
#         '매일유업')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '52',
#     '1837316797&ver')
# INSERT INTO items VALUES('2051091844&ver',
#         '[Gfresh]사세 버팔로윙 플러스1KG+버팔로스틱 플러스1KG (20%)',
#         39900,
#         28500,
#         0,
#         'Gfresh')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '53',
#     '2051091844&ver')
# INSERT INTO items VALUES('2064000271&ver',
#         '차일드아카데미  교과서 속 시리즈 30권세트 (지리/정치/경제)',
#         91000,
#         82700,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '54',
#     '2064000271&ver')
# INSERT INTO items VALUES('1766184747&ver',
#         '[릴리유]릴리유 퓨어퍼플 물티슈 캡72매X10팩(1BOX)',
#         40900,
#         15900,
#         0,
#         '릴리유')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '55',
#     '1766184747&ver')
# INSERT INTO items VALUES('1827768985&ver',
#         '[래핑차일드]래핑차일드 맨투맨/팬츠/점퍼 특가',
#         46300,
#         13900,
#         0,
#         '래핑차일드')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '56',
#     '1827768985&ver')
# INSERT INTO items VALUES('1350339365&ver',
#         '[지오다노]지오다노 스프링세일 반팔 오픈/테리/팬츠 ~73%OFF',
#         40000,
#         12000,
#         0,
#         '지오다노')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '57',
#     '1350339365&ver')
# INSERT INTO items VALUES('2060517179&ver',
#         '[노부영](제이와이북스) 노부영 에릭칼 베리베어 8종',
#         110000,
#         69500,
#         0,
#         '노부영')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '58',
#     '2060517179&ver')
# INSERT INTO items VALUES('2031972982&ver',
#         '듀오백 슬림 접이식 좌식의자 리프 DK 921',
#         54900,
#         47060,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '59',
#     '2031972982&ver')
# INSERT INTO items VALUES('1543877372&ver',
#         '우리네농산물 당진 해나루쌀 쌀10kg 삼광미 2020햅쌀특',
#         73800,
#         36900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '60',
#     '1543877372&ver')
# INSERT INTO items VALUES('1912263121&ver',
#         '식약처인증 KF94 마스크 100매/105매 (1매260원/250원) (1020_DEAL)',
#         26000,
#         26000,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '61',
#     '1912263121&ver')
# INSERT INTO items VALUES('1788265790&ver',
#         '[유한킴벌리]릴리유 퓨어미니 물티슈 20매 X 16팩(1BOX)',
#         20000,
#         10000,
#         0,
#         '유한킴벌리')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '62',
#     '1788265790&ver')
# INSERT INTO items VALUES('1677882918&ver',
#         '패션페스타22% 홈쇼핑 티셔츠 8종세트/빅사이즈/자켓',
#         99600,
#         29900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '63',
#     '1677882918&ver')
# INSERT INTO items VALUES('1911383377&ver',
#         '[닥터지](1+1) 약산성 레드블레미쉬 클리어 수딩폼 150ml +증정',
#         36000,
#         25200,
#         0,
#         '닥터지')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '64',
#     '1911383377&ver')
# INSERT INTO items VALUES('2007098317&ver',
#         '[세타필]세타필 카카오프렌즈1000개한정판(로션+로션+굿즈3종)',
#         39000,
#         22900,
#         0,
#         '세타필')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '65',
#     '2007098317&ver')
# INSERT INTO items VALUES('1846418319&ver',
#         '[녹십초]프로 프리바이오틱스유산균 2g 30포x6+1박스/단독특가',
#         26800,
#         18800,
#         0,
#         '녹십초')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '66',
#     '1846418319&ver')
# INSERT INTO items VALUES('2063127844&ver',
#         '[대저농협] 대저 짭짤이 토마토 프리미엄과 (S  2S사이즈) 2박스 1.5kg(총3kg)',
#         49900,
#         49900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '67',
#     '2063127844&ver')
# INSERT INTO items VALUES('1793107522&ver',
#         '[카레여왕]카레여왕분말 108g x 6개 골라담기',
#         17400,
#         13900,
#         0,
#         '청정원')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '68',
#     '1793107522&ver')
# INSERT INTO items VALUES('1508347298&ver',
#         '제주안심밥상 돼지특수부위 뒷고기(구이용) 4팩 1kg',
#         7800,
#         3900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '69',
#     '1508347298&ver')
# INSERT INTO items VALUES('2042774529&ver',
#         '[Gfresh]씹푸스 쥐치포 (특대) 300g 7-9장 /20% 쿠폰가 7620원',
#         16500,
#         9900,
#         0,
#         'Gfresh')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '70',
#     '2042774529&ver')
# INSERT INTO items VALUES('1614191721&ver',
#         '[진라면]진라면 매운맛 40봉',
#         30000,
#         18800,
#         0,
#         '오뚜기')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '71',
#     '1614191721&ver')
# INSERT INTO items VALUES('1830048238&ver',
#         '[이너리즘]이너리즘 에어 3장세트 시원하고 편한 쿨 모달나시 외',
#         28300,
#         8500,
#         0,
#         '이너리즘')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '72',
#     '1830048238&ver')
# INSERT INTO items VALUES('2053612243&ver',
#         '[Gfresh]어가찬 바다일품 백진미채  1kg/국내가공/20%추가할인',
#         29900,
#         17900,
#         0,
#         'Gfresh')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '73',
#     '2053612243&ver')
# INSERT INTO items VALUES('1655241628&ver',
#         '[구글플레이](카드가능) 기프트코드 3만원 / 구글 기프트카드',
#         30000,
#         28500,
#         0,
#         '구글플레이')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '74',
#     '1655241628&ver')
# INSERT INTO items VALUES('1590106776&ver',
#         '[아몬드브리즈]아몬드브리즈 오리지널 190ML 48팩',
#         27900,
#         20900,
#         0,
#         '매일유업')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '75',
#     '1590106776&ver')
# INSERT INTO items VALUES('990518421&ver',
#         '[CW청우]왕찹쌀 모나카 27개입 810g/과자/간식/팥/찰떡',
#         23100,
#         11000,
#         0,
#         'CW청우')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '76',
#     '990518421&ver')
# INSERT INTO items VALUES('2007110767&ver',
#         '소막 황사보건용 KF94 마스크 국내생산 100매 (10x10)',
#         15800,
#         14700,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '77',
#     '2007110767&ver')
# INSERT INTO items VALUES('1835916262&ver',
#         '브리치x바이미쓰리 패션페스타22% 니트/맨투맨/팬츠',
#         46300,
#         13900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '78',
#     '1835916262&ver')
# INSERT INTO items VALUES('1556146674&ver',
#         '[홈스타]홈스타 뿌리는 곰팡이싹 500ml x4+1L증정',
#         18300,
#         10900,
#         0,
#         '홈스타')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '79',
#     '1556146674&ver')
# INSERT INTO items VALUES('1895033274&ver',
#         '[키즈마루]국산 3중 비말차단 마스크  300매 KF-AD MB필터 마스크',
#         18400,
#         15910,
#         0,
#         '키즈마루')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '80',
#     '1895033274&ver')
# INSERT INTO items VALUES('2045196008&ver',
#         '[올리빙]플라스틱 수납정리함 리빙박스 도트72L 2+2 스티커포함',
#         69900,
#         22900,
#         0,
#         '올리빙')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '81',
#     '2045196008&ver')
# INSERT INTO items VALUES('857603217&ver',
#         '[동서]포스트 오레오오즈500g x2개입 +사은품/포스트/씨리얼',
#         29600,
#         14800,
#         0,
#         '동서')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '82',
#     '857603217&ver')
# INSERT INTO items VALUES('2059919685&ver',
#         '[Gfresh]스페셜티 에티오피아 예가체프 460mlx20펫 쿠폰가14680',
#         39000,
#         19500,
#         0,
#         'Gfresh')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '83',
#     '2059919685&ver')
# INSERT INTO items VALUES('1607527508&ver',
#         '[동원참치]라이트 스탠다드 참치 100g 15캔 원터치',
#         17900,
#         17900,
#         0,
#         '동원에프앤비')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '84',
#     '1607527508&ver')
# INSERT INTO items VALUES('1309233372&ver',
#         '패션페스타22% 프라이데이/봄신상/빅사이즈/루즈핏',
#         39600,
#         11900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '85',
#     '1309233372&ver')
# INSERT INTO items VALUES('2065020625&ver',
#         '어린이용 골전도 이어폰',
#         99000,
#         29900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '86',
#     '2065020625&ver')
# INSERT INTO items VALUES('1107162855&ver',
#         '[프롬산타]패션페스타22% 남여 봄 양말/덧신 스니커즈로퍼발목',
#         23000,
#         6900,
#         0,
#         '프롬산타')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '87',
#     '1107162855&ver')
# INSERT INTO items VALUES('2059295707&ver',
#         '(행사상품)고시히카리초밥세트30입',
#         11990,
#         11930,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '88',
#     '2059295707&ver')
# INSERT INTO items VALUES('774079012&ver',
#         '패션페스타22% 걸스데일리 빅사이즈 원피스/티셔츠',
#         53000,
#         15900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '89',
#     '774079012&ver')
# INSERT INTO items VALUES('1953359487&ver',
#         '[온더바디]발을씻자 코튼 풋 샴푸 385ml 레몬+자몽+쿨링+사은품',
#         23900,
#         13500,
#         0,
#         '온더바디')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '90',
#     '1953359487&ver')
# INSERT INTO items VALUES('1561173843&ver',
#         '[매일유업]매일두유 99.89 190ml 48팩/두유',
#         30900,
#         18900,
#         0,
#         '매일유업')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '91',
#     '1561173843&ver')
# INSERT INTO items VALUES('1975599165&ver',
#         '[롯데제과]퀘이커 마시는오트밀그레인서리태 낱봉 20개입  1박스',
#         15900,
#         15900,
#         0,
#         '롯데제과')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '92',
#     '1975599165&ver')
# INSERT INTO items VALUES('607466490&ver',
#         '[난닝구]난닝구 패션페스타22% 봄 원피스/맨투맨/셔츠/자켓',
#         59600,
#         17900,
#         0,
#         '난닝구')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '93',
#     '607466490&ver')
# INSERT INTO items VALUES('1749181524&ver',
#         '[매일유업]매일 소화가잘되는우유 멸균 190ML 24팩',
#         20500,
#         15500,
#         0,
#         '매일유업')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '94',
#     '1749181524&ver')
# INSERT INTO items VALUES('2036227474&ver',
#         '[Gfresh]착한떡 제주해풍쑥개떡 1kg + 1kg  총 2kg',
#         25800,
#         12900,
#         0,
#         'Gfresh')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '95',
#     '2036227474&ver')
# INSERT INTO items VALUES('1609433507&ver',
#         '[육개장]육개장사발면6입+김치사발면6입+짜파게티범벅6입',
#         19900,
#         12900,
#         0,
#         '농심')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '96',
#     '1609433507&ver')
# INSERT INTO items VALUES('1589098023&ver',
#         '[고려은단]고려은단 비타민C 1000 600정(20개월분)',
#         79800,
#         39900,
#         0,
#         '고려은단')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '97',
#     '1589098023&ver')
# INSERT INTO items VALUES('2043885240&ver',
#         '[Gfresh]바다내음 태안 활 쭈꾸미 1kg / 20% 쿠폰가 19120',
#         34200,
#         23900,
#         0,
#         'Gfresh')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '98',
#     '2043885240&ver')
# INSERT INTO items VALUES('858294811&ver',
#         '황금미가 쌀 20kg 20년산 (당일도정)',
#         109800,
#         54900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '99',
#     '858294811&ver')
# INSERT INTO items VALUES('214340838&ver',
#         '[겔업]겔업 고농축 액체세제 2.5L x 4개 세탁세제 총10000ml',
#         25000,
#         7900,
#         0,
#         '겔업')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '100',
#     '214340838&ver')
# INSERT INTO items VALUES('1787957433&ver',
#         '[사조참치]참치3종세트(살코기100gx2+고추85gx5+마일드85gx5)',
#         19700,
#         11700,
#         0,
#         '사조참치')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '101',
#     '1787957433&ver')
# INSERT INTO items VALUES('1277558140&ver',
#         '[프롬산타]패션페스타22% 봄 면양말/실리콘덧신 남자여자발목',
#         23000,
#         6900,
#         0,
#         '프롬산타')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '102',
#     '1277558140&ver')
# INSERT INTO items VALUES('1578966236&ver',
#         '[칠성사이다]칠성 사이다 210ml x 30캔',
#         15900,
#         11900,
#         0,
#         '롯데칠성')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '103',
#     '1578966236&ver')
# INSERT INTO items VALUES('805459425&ver',
#         '[슈프림]남녀공용 후드티 남성여성 빅사이즈티셔츠 긴팔맨투맨',
#         33000,
#         9900,
#         0,
#         '슈프림')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '104',
#     '805459425&ver')
# INSERT INTO items VALUES('1826127999&ver',
#         '패션페스타22%플라이핏 봄신상 롱가디건 /니트',
#         26900,
#         8900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '105',
#     '1826127999&ver')
# INSERT INTO items VALUES('1686035302&ver',
#         '[제주삼다수]제주삼다수 2L 12병/생수전문배송',
#         13400,
#         11900,
#         0,
#         '제주삼다수')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '106',
#     '1686035302&ver')
# INSERT INTO items VALUES('1564471554&ver',
#         '[가야농장]가야농장  1.5L 인기 5종기획(알토감사복)',
#         10750,
#         8900,
#         0,
#         '웅진')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '107',
#     '1564471554&ver')
# INSERT INTO items VALUES('2037109133&ver',
#         '[Gfresh]사세 버팔로윙 1kg+버팔로봉 1kg',
#         39900,
#         27900,
#         0,
#         'Gfresh')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '108',
#     '2037109133&ver')
# INSERT INTO items VALUES('2059490637&ver',
#         '비룡소 사회는 쉽다 1-11권 세트 (전11권)',
#         122200,
#         110000,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '109',
#     '2059490637&ver')
# INSERT INTO items VALUES('1755194607&ver',
#         '[웅진주니어]웅진주니어 에바 알머슨 이야기 (전3권)',
#         45000,
#         40500,
#         0,
#         '웅진주니어')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '110',
#     '1755194607&ver')
# INSERT INTO items VALUES('667938939&ver',
#         '이니스프리 봄맞이 이니데이 주요라인 UP TO 20%',
#         35000,
#         28000,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '111',
#     '667938939&ver')
# INSERT INTO items VALUES('333425585&ver',
#         '패션페스타22% 캔마트 신상베스트/티셔츠/팬츠/원피스',
#         79600,
#         23900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '112',
#     '333425585&ver')
# INSERT INTO items VALUES('767423273&ver',
#         '[싸이닉](22%중복) 싸이닉 착한 비건 스킨케어 외 BEST ~72%',
#         60000,
#         19800,
#         0,
#         '싸이닉')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '113',
#     '767423273&ver')
# INSERT INTO items VALUES('994075556&ver',
#         '(국산) 마녀 열무김치2kg',
#         16500,
#         9900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '114',
#     '994075556&ver')
# INSERT INTO items VALUES('1754998124&ver',
#         '[크리넥스]크리넥스 3겹 데코소프트 33MX24롤 X2팩화장지/휴지',
#         75000,
#         29900,
#         0,
#         '크리넥스')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '115',
#     '1754998124&ver')
# INSERT INTO items VALUES('1824005992&ver',
#         '[유닉스]메탈티 무광블랙 1600W 헤어 드라이기 UN-A1610 접이식',
#         23900,
#         23900,
#         0,
#         '유닉스')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '116',
#     '1824005992&ver')
# INSERT INTO items VALUES('1284344651&ver',
#         '패션페스타22% 데이뮤즈 원피스/자켓/가디건/바지/롱',
#         33000,
#         9900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '117',
#     '1284344651&ver')
# INSERT INTO items VALUES('981861372&ver',
#         '[매일우유]매일 멸균우유 200ml 48팩/우유',
#         31900,
#         23900,
#         0,
#         '매일유업')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '118',
#     '981861372&ver')
# INSERT INTO items VALUES('1883532433&ver',
#         '[대우]대우 와플메이커 3 in 1(메탈블랙) 분리형',
#         31900,
#         27900,
#         0,
#         '대우')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '119',
#     '1883532433&ver')
# INSERT INTO items VALUES('1807235725&ver',
#         '[에뛰드]미세먼지 주의 클렌징 기초 특가 최대 60% 할인',
#         50000,
#         25000,
#         0,
#         '에뛰드')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '120',
#     '1807235725&ver')
# INSERT INTO items VALUES('1761073392&ver',
#         '[동원에프앤비]동원 샘물 2Lx6병x6팩(총36병)',
#         24700,
#         17300,
#         0,
#         '동원에프앤비')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '121',
#     '1761073392&ver')
# INSERT INTO items VALUES('701343009&ver',
#         '(전단상품)[20년산]The Plus 좋은쌀_20KG 포 ',
#         55900,
#         55620,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '122',
#     '701343009&ver')
# INSERT INTO items VALUES('1288403984&ver',
#         '[노스페이스화이트라벨]봄 바람막이/반팔티/맨투맨/자켓/볼캡/신발 인기상품',
#         149000,
#         45000,
#         0,
#         '노스페이스화이트라벨')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '123',
#     '1288403984&ver')
# INSERT INTO items VALUES('1774601970&ver',
#         '[매일우유]매일 멸균우유 저지방 1프로 200ML 48팩 무배',
#         28400,
#         21400,
#         0,
#         '매일유업')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '124',
#     '1774601970&ver')
# INSERT INTO items VALUES('1651278574&ver',
#         '[햇반]햇반 매일잡곡밥 210g 24개 유통기한 2021-07-07',
#         27900,
#         22900,
#         0,
#         '햇반')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '125',
#     '1651278574&ver')
# INSERT INTO items VALUES('1835879609&ver',
#         '엠에스 치간칫솔 I형 SSSS(0.4mm) 50P x 2팩 (총100P)',
#         35700,
#         11900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '126',
#     '1835879609&ver')
# INSERT INTO items VALUES('1926039799&ver',
#         '리빙앳홈 에어프라이어종이호일60매 거름망세트16cm',
#         22000,
#         8500,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '127',
#     '1926039799&ver')
# INSERT INTO items VALUES('2057449056&ver',
#         '[지오다노]지오다노 주니어 쇼케이스 단독_티셔츠/데님/팬츠',
#         49000,
#         15960,
#         0,
#         '지오다노')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '128',
#     '2057449056&ver')
# INSERT INTO items VALUES('1577510972&ver',
#         '[락토핏]락토핏 생유산균 골드 50포 3통(150일분)+골드 30포',
#         37900,
#         37900,
#         0,
#         '락토핏')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '129',
#     '1577510972&ver')
# INSERT INTO items VALUES('2064961301&ver',
#         'LINKABLE 휴대용 DVD플레이어 10.1인치(25일부터 배송)',
#         209000,
#         128000,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '130',
#     '2064961301&ver')
# INSERT INTO items VALUES('343955943&ver',
#         '[쁘리엘르]1+1 발매트 주방매트 욕실 현관 거실 순면 자카드',
#         29600,
#         8900,
#         0,
#         '쁘리엘르')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '131',
#     '343955943&ver')
# INSERT INTO items VALUES('169295221&ver',
#         '신상/남자청바지/남성/빅사이즈/스판/슬랙스/바지',
#         52600,
#         15800,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '132',
#     '169295221&ver')
# INSERT INTO items VALUES('761396673&ver',
#         '(행사상품)딸기_1KG 박스 ',
#         6990,
#         6990,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '133',
#     '761396673&ver')
# INSERT INTO items VALUES('2037963795&ver',
#         '[톨스토이]경제전집 통큰 경제동화 전68권 세트 : 경제개념동화',
#         250000,
#         212840,
#         0,
#         '톨스토이')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '134',
#     '2037963795&ver')
# INSERT INTO items VALUES('1741993279&ver',
#         '[에그머니](카드가능)(에그머니) 온라인 게임상품권 3만원',
#         30000,
#         27000,
#         0,
#         '에그머니')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '135',
#     '1741993279&ver')
# INSERT INTO items VALUES('1938546760&ver',
#         '[하기스매직팬티]하기스 매직팬티뉴컴포트 5단계 공용 70P 1BOX',
#         80900,
#         32900,
#         0,
#         '하기스')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '136',
#     '1938546760&ver')
# INSERT INTO items VALUES('2031185319&ver',
#         '[롯데칠성]칠성사이다 제로 500ml x 20펫',
#         29900,
#         24900,
#         0,
#         '롯데칠성')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '137',
#     '2031185319&ver')
# INSERT INTO items VALUES('2037966646&ver',
#         '[대상]마무리볶음밥3종(닭갈비/고깃집/훈제오리) 12개(각4개)',
#         27000,
#         23900,
#         0,
#         '대상')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '138',
#     '2037966646&ver')
# INSERT INTO items VALUES('1695814034&ver',
#         '[레시피박스]레시피박스 어린이 약산성 폼클렌징 1+3 총4개',
#         27900,
#         27900,
#         0,
#         '레시피박스')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '139',
#     '1695814034&ver')
# INSERT INTO items VALUES('399488337&ver',
#         '[젤리스푼]아동복/여아의류/레깅스/자켓/점퍼/여아옷/상하복',
#         46300,
#         13900,
#         0,
#         '젤리스푼')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '140',
#     '399488337&ver')
# INSERT INTO items VALUES('1961164039&ver',
#         '[롯데제과]퀘이커 마시는 오트밀 4종 혼합 20개입 +사은품',
#         29900,
#         29900,
#         0,
#         '롯데제과')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '141',
#     '1961164039&ver')
# INSERT INTO items VALUES('2034804563&ver',
#         '[컬럼비아](대구신세계)컬럼비아 시애틀 락 남녀 커플 봄자켓[YM3012 YL3012 YL3011]',
#         79000,
#         63200,
#         0,
#         '컬럼비아')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '142',
#     '2034804563&ver')
# INSERT INTO items VALUES('215673140&ver',
#         '스위트바니/패션페스타22%롱원피스티셔츠/맨투맨/반팔',
#         43000,
#         12900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '143',
#     '215673140&ver')
# INSERT INTO items VALUES('1883764136&ver',
#         '[폴햄]폴햄 반팔 티셔츠외 모음전',
#         19600,
#         5900,
#         0,
#         '폴햄')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '144',
#     '1883764136&ver')
# INSERT INTO items VALUES('1655242060&ver',
#         '[구글플레이](카드가능) 기프트코드 5만원 / 구글 기프트카드',
#         50000,
#         47500,
#         0,
#         '구글플레이')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '145',
#     '1655242060&ver')
# INSERT INTO items VALUES('1834224973&ver',
#         '[팸퍼스]팸퍼스 베이비드라이 5단계 팬티형기저귀36p 4팩',
#         60900,
#         57500,
#         0,
#         '팸퍼스')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '146',
#     '1834224973&ver')
# INSERT INTO items VALUES('1817550305&ver',
#         '[다우니퍼퓸]다우니 퍼퓸 블랙 미스티크 향 1L 6개 +사은품',
#         49800,
#         29860,
#         0,
#         '다우니')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '147',
#     '1817550305&ver')
# INSERT INTO items VALUES('2065851517&ver',
#         '[폴햄]폴햄  21SS 최신상 이지웨어 팬츠 2종 28~36 블랙/멜',
#         35900,
#         35900,
#         0,
#         '폴햄')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '148',
#     '2065851517&ver')
# INSERT INTO items VALUES('1791759756&ver',
#         '[스카트]스카트 THE 버블 수세미 그레이 50매X3롤',
#         30900,
#         11900,
#         0,
#         '스카트')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '149',
#     '1791759756&ver')
# INSERT INTO items VALUES('1498699891&ver',
#         '[이지바이](패션페스타22%)봄신상 티셔츠/트레이닝바지/바람막이',
#         26300,
#         7900,
#         0,
#         '이지바이')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '150',
#     '1498699891&ver')
# INSERT INTO items VALUES('1682714054&ver',
#         '[아몬드브리즈]아몬드브리즈 뉴트리 플러스 프로틴 190ML 24팩',
#         21900,
#         14900,
#         0,
#         '매일유업')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '151',
#     '1682714054&ver')
# INSERT INTO items VALUES('1551794470&ver',
#         '데이데이 패션페스타22% 블라우스/맨투맨/팬츠/원피스',
#         33000,
#         9900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '152',
#     '1551794470&ver')
# INSERT INTO items VALUES('1653475521&ver',
#         '[홈스타]홈스타 락스와세제 후로랄파인 750ML x4+락스1L증정',
#         16910,
#         10900,
#         0,
#         '홈스타')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '153',
#     '1653475521&ver')
# INSERT INTO items VALUES('1919112136&ver',
#         'EXR SS 트랙수트 외 자켓/티셔츠/팬츠',
#         60000,
#         19900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '154',
#     '1919112136&ver')
# INSERT INTO items VALUES('776582823&ver',
#         '패션페스타22% 엄마옷로즈맘  5060중년여성의류',
#         43000,
#         12900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '155',
#     '776582823&ver')
# INSERT INTO items VALUES('1649311897&ver',
#         '[비비고]비비고 사골곰탕 500g 18개',
#         20900,
#         16900,
#         0,
#         '비비고')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '156',
#     '1649311897&ver')
# INSERT INTO items VALUES('1999684957&ver',
#         '구운아몬드 1kg',
#         17800,
#         8900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '157',
#     '1999684957&ver')
# INSERT INTO items VALUES('1345149344&ver',
#         '브리치x럭키567 패션페스타22% 맨투맨/원피스/니트',
#         46300,
#         13900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '158',
#     '1345149344&ver')
# INSERT INTO items VALUES('2060813730&ver',
#         '뉴발란스 327 남성 스니커즈 컬러 택1 (MS327)',
#         139000,
#         92050,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '159',
#     '2060813730&ver')
# INSERT INTO items VALUES('1791565626&ver',
#         '[에그머니](카드가능)(에그머니) 온라인 게임상품권 5만원',
#         50000,
#         45000,
#         0,
#         '에그머니')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '160',
#     '1791565626&ver')
# INSERT INTO items VALUES('1514799411&ver',
#         '[케라시스]케라시스 퍼퓸 샴푸 600mlx5(러1엘1퓨1블1글1)쿠폰할인',
#         35800,
#         17900,
#         0,
#         '애경')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '161',
#     '1514799411&ver')
# INSERT INTO items VALUES('2032891975&ver',
#         '첫출하대저토마토  3-4번M(중과)2.5kg 산지직송',
#         39800,
#         19900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '162',
#     '2032891975&ver')
# INSERT INTO items VALUES('2060695122&ver',
#         '[디스커버리]공용 조거 맥스 DXSHH1031DXSHH2031DXSHH3031',
#         90300,
#         73600,
#         0,
#         '디스커버리')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '163',
#     '2060695122&ver')
# INSERT INTO items VALUES('701546350&ver',
#         '(1+1)미국_필라델피아크림치즈 플레인 _200G',
#         5590,
#         5570,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '164',
#     '701546350&ver')
# INSERT INTO items VALUES('373058782&ver',
#         '다온샵 /패션페스타22%+10%/청바지/배기/슬랙스/~3XL',
#         33000,
#         9900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '165',
#     '373058782&ver')
# INSERT INTO items VALUES('1654805524&ver',
#         '[구글플레이](카드가능) 기프트코드 1만원 / 구글 기프트카드',
#         10000,
#         9500,
#         0,
#         '구글플레이')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '166',
#     '1654805524&ver')
# INSERT INTO items VALUES('1919425682&ver',
#         '뼈없는 직화불닭발 150g x 3팩 (총 450g)',
#         14000,
#         11900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '167',
#     '1919425682&ver')
# INSERT INTO items VALUES('1995589059&ver',
#         '[에이블루]특허받은의자 NEW 에이블루 커블체어 와이더 2+1세트',
#         119600,
#         119010,
#         0,
#         '에이블루')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     ALL',
#     'ALL',
#     '168',
# ...
#         5400,
#         4860,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '5',
#     '633951987&ver')
# INSERT INTO items VALUES('1215738311&ver',
#         '시루콧토 우루우루 화장솜 40매x5팩',
#         11500,
#         11500,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '6',
#     '1215738311&ver')
# INSERT INTO items VALUES('703025059&ver',
#         '[더바디샵]점보 티트리 오일 20ML(97253)/ 더바디샵',
#         21000,
#         18170,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '7',
#     '703025059&ver')
# INSERT INTO items VALUES('1757105149&ver',
#         '[아베다]갤러리아  아베다 우든 패들 브러쉬',
#         36000,
#         28800,
#         0,
#         '아베다')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '8',
#     '1757105149&ver')
# INSERT INTO items VALUES('169617177&ver',
#         '딜론 다용도 화장솜 100매 x 9개/순면/델론 코스트코',
#         18420,
#         16580,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '9',
#     '169617177&ver')
# INSERT INTO items VALUES('2010152628&ver',
#         'NEW 오제끄 실크 고마주 바디필링 프리미엄 방송 특집패키지 ',
#         59900,
#         47930,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '10',
#     '2010152628&ver')
# INSERT INTO items VALUES('1531221443&ver',
#         '[예다움]화장품 정리함 정리대 보관함 화장대정리함 아크릴',
#         19900,
#         17900,
#         0,
#         '예다움')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '11',
#     '1531221443&ver')
# INSERT INTO items VALUES('1706211505&ver',
#         '[피카소브러쉬]피카소꼴레지오니 전상품 10% 브랜드 세일',
#         40000,
#         26100,
#         0,
#         '피카소브러쉬')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '12',
#     '1706211505&ver')
# INSERT INTO items VALUES('219350818&ver',
#         '[다크니스]다크니스 속눈썹/샤몽 속눈썹/10개/쌍거풀액/접착제',
#         32000,
#         16000,
#         0,
#         '다크니스')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '13',
#     '219350818&ver')
# INSERT INTO items VALUES('529254643&ver',
#         '[아이참]이쁠라 아이참 5개 쌍꺼풀테이프 쌍커풀테이프',
#         7100,
#         7100,
#         0,
#         '아이참')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '14',
#     '529254643&ver')
# INSERT INTO items VALUES('883441069&ver',
#         '[라벨영]쇼킹 아이글루 1+1+1/안전성분+눈쳐짐방짐/쌍커플액',
#         33000,
#         9900,
#         0,
#         '라벨영')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '15',
#     '883441069&ver')
# INSERT INTO items VALUES('1273156662&ver',
#         '[프레티]엠보 순면100% 화장솜1000매/형광증백제NO/클렌징워터',
#         30000,
#         16900,
#         0,
#         '프레티')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '16',
#     '1273156662&ver')
# INSERT INTO items VALUES('1575017695&ver',
#         '[오릭스]오릭스 바디오일 600ml x 12개 마사지 베이비오일',
#         32900,
#         29610,
#         0,
#         '오릭스')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '17',
#     '1575017695&ver')
# INSERT INTO items VALUES('1853793397&ver',
#         '[메디플라워]순면100% 깔끔 엠보싱 대용량 화장솜 520매x2/총1040매',
#         10900,
#         10900,
#         0,
#         '메디플라워')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '18',
#     '1853793397&ver')
# INSERT INTO items VALUES('165290824&ver',
#         '1+1 이키루 미용가위세트(헤어+틴닝)/아기애견 앞머리',
#         15800,
#         11830,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '19',
#     '165290824&ver')
# INSERT INTO items VALUES('1709944305&ver',
#         '[메디플라워]메이크 셀프패드 화장솜 닥토패드 각질패드 본품 1+1',
#         10500,
#         9450,
#         0,
#         '메디플라워')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '20',
#     '1709944305&ver')
# INSERT INTO items VALUES('1184373662&ver',
#         '반영구색소/뉴홀릭엠보색소/번트토스트/머신겸용',
#         25000,
#         25000,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '21',
#     '1184373662&ver')
# INSERT INTO items VALUES('1949079667&ver',
#         'NEW 오제끄 실크 고마주 바디필링 프리미엄 방송 최다패키지',
#         59900,
#         50920,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '22',
#     '1949079667&ver')
# INSERT INTO items VALUES('1793437486&ver',
#         '클리오네 속눈썹펌 리프트 파마 키트 세트 15회분',
#         26500,
#         26500,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '23',
#     '1793437486&ver')
# INSERT INTO items VALUES('724074816&ver',
#         '뷰티영 퍼레스 미간패치/ 퍼레스 패치',
#         45000,
#         45000,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '24',
#     '724074816&ver')
# INSERT INTO items VALUES('1616185800&ver',
#         '[내츄럴플러스]내츄럴플러스 유기농 화장솜 원형 100매 3개 2세트',
#         14900,
#         14830,
#         0,
#         '내츄럴플러스')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '25',
#     '1616185800&ver')
# INSERT INTO items VALUES('161609129&ver',
#         '[화이트래빗]발명특허 항균엠보 화장솜600매/1000매 원단설비보유',
#         6900,
#         6210,
#         0,
#         '화이트래빗')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '26',
#     '161609129&ver')
# INSERT INTO items VALUES('1274391867&ver',
#         '사은품+무료배송(커트가위+숱가위) 2개1세트 미용가위',
#         15200,
#         15200,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '27',
#     '1274391867&ver')
# INSERT INTO items VALUES('696549087&ver',
#         'Haruka 고급미용가위 이발 숱 틴닝 전문가용 앞머리',
#         9900,
#         9750,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '28',
#     '696549087&ver')
# INSERT INTO items VALUES('927866703&ver',
#         '[시세이도]시세이도 속눈썹뷰러 213 / 마끼아쥬 뷰러',
#         13400,
#         12060,
#         0,
#         '시세이도')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '29',
#     '927866703&ver')
# INSERT INTO items VALUES('1780942733&ver',
#         '[헤라]헤라 블랙쿠션 퍼프 6/10매',
#         10500,
#         9450,
#         0,
#         '헤라')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '30',
#     '1780942733&ver')
# INSERT INTO items VALUES('1710011863&ver',
#         '[메디플라워]메이크 셀프패드 화장솜 닥토패드 각질패드 본품+리필',
#         14900,
#         14900,
#         0,
#         '메디플라워')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '31',
#     '1710011863&ver')
# INSERT INTO items VALUES('1172184267&ver',
#         '[입큰]순면 100% 화장솜 240매(80매X3팩) 無형광 천연화장솜',
#         5900,
#         5310,
#         0,
#         '입큰')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '32',
#     '1172184267&ver')
# INSERT INTO items VALUES('676645335&ver',
#         '[더페이스샵]더페이스샵 데일리 뷰티툴즈 면봉 300pcs x 10개',
#         10000,
#         8900,
#         0,
#         '더페이스샵')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '33',
#     '676645335&ver')
# INSERT INTO items VALUES('163328502&ver',
#         '타투스티커1위 러브리타투/어린이/행사/할로윈',
#         2000,
#         1990,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '34',
#     '163328502&ver')
# INSERT INTO items VALUES('1473909386&ver',
#         '셀프 미용가운 셀프커트 컷트보 염색가운 어린이 이발',
#         2980,
#         2980,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '35',
#     '1473909386&ver')
# INSERT INTO items VALUES('682241668&ver',
#         '셀프 파마 롯드 헤어 롤 미용 재료 용품 염색 빗',
#         900,
#         900,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '36',
#     '682241668&ver')
# INSERT INTO items VALUES('702685111&ver',
#         '5+2타투스티커/헤나/레터링/문신/tattoo/컬러패션타투',
#         490,
#         490,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '37',
#     '702685111&ver')
# INSERT INTO items VALUES('1556533074&ver',
#         '[어반리브즈]어반리브즈 무표백 무형광 화장솜 (140매) 5개',
#         24000,
#         18000,
#         0,
#         '어반리브즈')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '38',
#     '1556533074&ver')
# INSERT INTO items VALUES('151098549&ver',
#         '접이식눈썹칼x30개/안전커버/면도칼/수정칼/제모기/털',
#         16900,
#         16820,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '39',
#     '151098549&ver')
# INSERT INTO items VALUES('2054117019&ver',
#         '화장품 정리함 보관함 수납함 대형',
#         20500,
#         20300,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '40',
#     '2054117019&ver')
# INSERT INTO items VALUES('1808900936&ver',
#         'ANLAN 안란 속눈썹고데기 아이컬 매직컬 뷰러',
#         20700,
#         20700,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '41',
#     '1808900936&ver')
# INSERT INTO items VALUES('724076623&ver',
#         '[뷰티영]뷰티영 퍼레스 눈가 눈밑 패치/ 퍼레스 패치',
#         45000,
#         45000,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '42',
#     '724076623&ver')
# INSERT INTO items VALUES('958816919&ver',
#         '(2+1)천원 종이면봉 개별포장 _100P',
#         1000,
#         1000,
#         0,
#         '')
# INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
#     화장품/헤어',
#     '화장소품',
#     '43',
#     '958816919&ver')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-493f913c75ac> in <module>
#      10 categories = soup.select('div.gbest-cate ul.by-group li a')
#      11 for category in categories:
# ---> 12     get_category('http://corners.gmarket.co.kr/'+category['href'], category.get_text())
#
# <ipython-input-64-27d3cdb15931> in get_category(category_link, category_name)
#      11         soup = bs(res.content, 'html.parser')
#      12
# ---> 13         get_items(soup, category_name, sub_category.get_text())
#      14
#      15         print('http://corners.gmarket.co.kr/'+sub_category['href'], sub_category.get_text())
#
# <ipython-input-63-318e7cb17a6c> in get_items(html, category_name, sub_category_name)
#      28         item_code = product_link['href'].split('=')[1]
#      29
# ---> 30         res = requests.get(product_link.attrs['href'])
#      31         soup = bs(res.content, 'html.parser')
#      32         provider = soup.select_one('div.item-topinfo_headline > p > span.text__brand > span')
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
def get_category(category_link, category_name):
    print(category_link, category_name)
    res = requests.get(category_link)
    soup = bs(res.content, 'html.parser')
    
    get_items(soup, category_name, 'ALL')
    
    sub_categories = soup.select('div.navi.group ul li > a')
    for sub_category in sub_categories:
        res = requests.get('http://corners.gmarket.co.kr/'+sub_category['href'])
        soup = bs(res.content, 'html.parser')
        
        get_items(soup, category_name, sub_category.get_text())
        
        print('http://corners.gmarket.co.kr/'+sub_category['href'], sub_category.get_text())

# %% [markdown]
# ### main/sub category + 상품정보 크롤링 +  판매자 크롤링

# %%
def get_items(html, category_name, sub_category_name):
    items_result_list=list()
    best_item = html.select('div.best-list')
    for index, item in enumerate(best_item[1].select('li')):
        data_dict = dict()
        
        ranking = index+1
        title = item.select_one('a.itemname')
        ori_price = item.select_one('div.o-price')
        dis_price = item.select_one('div.s-price strong span')
        discount_percent = item.select_one('div.s-price en')
        
        if ori_price == None or ori_price.get_text() == '':
            ori_price = dis_price
        
        if dis_price == None:
            ori_price, dis_price = 0,0
        else:
            ori_price = ori_price.get_text().replace(',','').replace('원','')
            dis_price = dis_price.get_text().replace(',','').replace('원','')
        
        if discount_percent == None or discount_percent.get_text() =='':
            discount_percent = 0
        else:
            discount_percent = discount_percent.get_text().replace('%','')
        
        product_link = item.select_one('div.thumb > a')
        item_code = product_link['href'].split('=')[1]
        
        res = requests.get(product_link.attrs['href'])
        soup = bs(res.content, 'html.parser')
        provider = soup.select_one('div.item-topinfo_headline > p > span.text__brand > span')
        if provider == None:
            provider = ''
        else:
            provider = provider.get_text()
        
        data_dict['category_name'] = category_name
        data_dict['sub_category_name'] = sub_category_name
        data_dict['ranking'] = ranking
        data_dict['title'] = title.get_text()
        data_dict['ori_price'] = ori_price
        data_dict['dis_price'] = dis_price
        data_dict['discount_percent'] = discount_percent
        data_dict['item_code'] = item_code
        data_dict['provider'] = provider 
        save_data(data_dict)
        #print(category_name, sub_category_name, ranking,item_code, provider,  title.get_text(), ori_price, dis_price, discount_percent)

# %% [markdown]
# ### Insert sql 만들기

# %% [markdown]
# ```
# CREATE TABLE ranking (
#     num INT AUTO_INCREMENT NOT NULL PRIMARY KEY,
#     main_category VARCHAR(50) NOT NULL,
#     sub_category VARCHAR(50) NOT NULL,
#     item ranking TINYINT UNSIGNED NOT NULL,
#     item_code VARCHAR(20) NOT NULL,
#     FOREIGN KEY (item_code) REFERENCES items(item_code));
#     ```

# %%
sql = """INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
""" + item_info['category_name'] + """',
'""" + item_info['sub_category_name'] + """', 
'""" + str(item_info['ranking']) + """', 
'""" + item_info['item_code'] + """')"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-3f0b9f9327c5> in <module>
#       1 sql = """INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
# ----> 2 """ + item_info['category_name'] + """',
#       3 '""" + item_info['sub_category_name'] + """',
#       4 '""" + str(item_info['ranking']) + """',
#       5 '""" + item_info['item_code'] + """')"""
#
# NameError: name 'item_info' is not defined

# %% [markdown]
# ```
#     CREATE TABLE items (
#     item_code VARCHAR(20) NOT NULL PRIMARY KEY,
#     title VARCHAR(200) NOT NULL,
#     ori_price INT NOT NULL,
#     dis_price INT NOT NULL,
#     discount_percent INT NOT NULL,
#     provider VARCHAR(100)
# );
# ```

# %%
sql = """INSERT INTO items VALUES('
""" + item_info['item_code'] + """',
'""" + item_info['title'] + """', 
""" + item_info['ori_price'] + """, 
""" + item_info['dis_price'] + """, 
""" + item_info['discount_percent'] + """, 
'""" + item_info['provider'] + """')"""    
sql
# Out:
# "INSERT INTO items VALUES('\n1164687842',\n'[오설록]프리미엄 티 컬렉션 40입 추석선물세트/쇼핑백지급', \n25000, \n18900, \n24, \n'오설록본사직영몰')"

# %%
item_info = {'category_name': 'ALL', 'sub_category_name': 'ALL', 'ranking': 1, 'title': '[오설록]프리미엄 티 컬렉션 40입 추석선물세트/쇼핑백지급', 'ori_price': '25000', 'dis_price': '18900', 'discount_percent': '24', 'item_code': '1164687842', 'provider': '오설록본사직영몰'}

# %%
def save_data(item_info):
    sql = """SELECT COUNT(*) FROM items WHERE item_code = '""" + item_info['item_code']+"""';"""
    cursor.execute(sql)
    result = cursor.fetchone() 
    if result[0] == 0:
        sql = """INSERT INTO items VALUES('""" + item_info['item_code'] + """',
        '""" + item_info['title'] + """', 
        """ + str(item_info['ori_price']) + """, 
        """ + str(item_info['dis_price']) + """, 
        """ + str(item_info['discount_percent']) + """, 
        '""" + item_info['provider'] + """')"""
        print(sql)
        cursor.execute(sql)

    sql = """INSERT INTO ranking (main_category, sub_category, item_ranking, item_code) VALUES('
    """ + item_info['category_name'] + """',
    '""" + item_info['sub_category_name'] + """', 
    '""" + str(item_info['ranking']) + """', 
    '""" + item_info['item_code'] + """')"""      
    cursor.execute(sql)
    print(sql)
